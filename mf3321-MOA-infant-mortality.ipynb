# %%
# Importing all the Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Importing the dataset
df = pd.read_csv('C:/Users/May/Desktop/MOU/measures-of-america.csv')
df.head()
# Out:
#         State  HD_Index  LifeExpectancy  MedianEarnings  Less_Than_HS  \
# 0     Alabama      4.04           75.42           25530         17.87
# 1      Alaska      5.06           78.29           32140          8.96
# 2     Arizona      4.89           79.64           27813         14.36
# 3    Arkansas      3.91           75.96           23992         17.06
# 4  California      5.40           80.77           30356         19.30
#
#    At_Least_HS  At_Least_BA  Grad_Degree  School_Enroll  \
# 0        82.13        21.91         8.00          76.13
# 1        91.04        27.92         9.43          71.15
# 2        85.64        25.90         9.22          74.15
# 3        82.94        19.49         6.31          75.70
# 4        80.70        30.09        10.96          78.43
#
#    Low_Birth_Weight_Infants  ...  Child_Poverty  Unemployment_Rate  \
# 0                      10.3  ...          27.72                5.9
# 1                       5.7  ...          12.91                6.2
# ...

# %%
# Creating easy reference for all column headings
print(df.columns)
# Out:
# Index(['State', 'HD_Index', 'LifeExpectancy', 'MedianEarnings', 'Less_Than_HS',
#        'At_Least_HS', 'At_Least_BA', 'Grad_Degree', 'School_Enroll',
#        'Low_Birth_Weight_Infants', '3and4yr_Not_Enroll_Preschool',
#        '4thGraders_Reading_Below_Prof', 'HS_Freshmen_Not_Grad_4yrs',
#        'Children_Under_6_Poverty', 'Adults_65_Poverty', 'Preschool_Enrollment',
#        'Students_ESL', 'Sp_Ed_Students', 'Econ_Disad_Students',
#        '4th_Grade _Nat_Assess_Reading', '8th_Grade_Nat_Assess_Math',
#        'Public_HS_Grad_Rate', 'HS_Grad_Enroll_College',
#        'Annual Costs of Public 4-Year College (average $)',
#        'Annual_Costs_Private_4yr_College', 'Annual_Costs_Public_2yr_College',
#        'Per_Pupil_Spending', 'State_Spending_Higher_Education',
#        'State_Spending_Academic_Research_Development',
#        'Indiv_Home_Internet_Access', 'Teenagers_Not_School_Not_Working',
#        'Total_Pop', 'Pop_Under_18', 'Pop_Over_65', 'Urban_Pop', 'Rural_Pop',
# ...

# %%
# Creating a dataframe with only columns needed; creating easy reference for available column headings
df = df[['State','MedianEarnings','Infant_Mortality_Rate', 'Births_Teen_Girls', 'Practicing_Physicians', 'Incarceration_Rate', 'State_Per_Capita_GDP', 'Poverty_Rate',
       'Child_Poverty','1860_Status', 'Plantation']]
print(df.columns)
# Out:
# Index(['State', 'MedianEarnings', 'Infant_Mortality_Rate', 'Births_Teen_Girls',
#        'Practicing_Physicians', 'Incarceration_Rate', 'State_Per_Capita_GDP',
#        'Poverty_Rate', 'Child_Poverty', '1860_Status', 'Plantation'],
#       dtype='object')

# %%
# Creating bar chart for OECD countries' IMR
label = ["Iceland","Luxembourg","Japan","Finland","Sweden","Slovenia","Norway","Czechia","Portugal","France","Spain","Italy","Greece","Germany","Denmark","South Korea","Ireland","Austria","Estonia","Belgium","Israel","Netherlands","Switzerland","Australia","UK","Lithuania","Canada","Hungary","New Zealand","Poland","Slovakia","USA","Latvia","Chile","Costa Rica","Turkey","Colombia","Mexico"]
data = [2.15,2.33,2.36,2.46,2.51,2.65,2.66,2.73,3.06,3.11,3.15,3.37,3.45,3.47,3.48,3.53,3.55,3.58,3.61,3.63,3.67,3.73,3.91,3.99,4.42,4.88,4.97,5.07,5.08,5.14,5.77,6.25,6.52,7.42,9.15,15.53,15.71,16.43,]
colors = ['teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','orangered','teal','teal','teal','teal','teal','teal','teal',]

fig, axs = plt.subplots(figsize=(22,10))
axs.bar(label, data, color=colors)
axs.set_title("Infant Mortality Rate in OECD Countries (2010)", fontsize=20, fontweight="bold")   
axs.set_xlabel("Country", fontsize=25)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=20)
axs.tick_params(labelsize=15, labelrotation=90)  
plt.grid(axis='y')
plt.show()

# %%
# Creating a pie chart of people without health insurance in US in 2010
data = [16,84]
label = ["Uninsured", "Insured"]
colors = ['mediumturquoise','teal']

fig, axs = plt.subplots(figsize=(10, 6)) # change figure size here
axs.pie(data, labels=label, autopct='%1.1f%%', startangle=90, colors=colors)

axs.axis('equal')
plt.title('Health Insurance Coverage in the US (2010)',fontweight="bold", fontsize=14, pad=20)
plt.show()

# %%
# Creating a pie chart of women with employer-provided insurance w/o maternity coverage in 2010
data = [62, 38]
label = ["No maternity coverage", "Maternity coverage"]
colors = ['mediumturquoise','teal']

fig, axs = plt.subplots(figsize=(10, 6)) # change figure size here
axs.pie(data, labels=label, autopct='%1.1f%%', startangle=90, colors=colors)

axs.axis('equal')
plt.title('Women w/ Employer-Provided Insurance in US (2010)',fontweight="bold", fontsize=14, pad=20)
plt.show()

# %%
# Calculating the 50-state mean and median IMR
df_IMR = df['Infant_Mortality_Rate']
IMR_mean = np.mean(df_IMR)
IMR_median = np.median(df_IMR)

print("The mean infant mortality rate, per 1,000 live births, for all 50 states is:", IMR_mean)
print("The median infant mortality rate, per 1,000 live births, for all 50 states is:", IMR_median)
# Out:
# The mean infant mortality rate, per 1,000 live births, for all 50 states is: 6.216799999999999
# The median infant mortality rate, per 1,000 live births, for all 50 states is: 6.32

# %%
# Creating bar chart for all states' IMR
data = df['Infant_Mortality_Rate']
label = df['State']

fig, axs = plt.subplots(figsize=(22,10))
axs.bar(label, data, color=('teal'))  
axs.set_title("Infant Mortality Rate in the US (2010)", fontsize=23, fontweight="bold")   
axs.set_xlabel("US States", fontsize=23)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=20)
axs.tick_params(labelsize=15, labelrotation=90)  
plt.grid(axis='y')
axs.axhline(IMR_median, color='orangered',ls='--')
plt.show()

# %%
# Creating a histogram of 50-state IMR
fig, axs = plt.subplots(figsize=(4,5))

axs.hist(df_IMR, color="teal", edgecolor="darkslategrey")
plt.title("50-State Distribution of IMR", fontsize=14, fontweight="bold")
axs.set_xlabel("IMR  (per 1,000 live births)", fontsize=11)
axs.set_ylabel("Frequency", fontsize=11)
axs.tick_params(labelsize=10)
plt.show()

# %%
# Creating a boxplot for 50-state IMR
fig, axs = plt.subplots(figsize=(4,5))
axs.boxplot(df_IMR)
plt.title('50-State Distribution of IMR', fontsize=12,fontweight="bold")
axs.set_xticklabels([''])
axs.set_ylabel('IMR (per 1,000 live births)', fontsize=12)
axs.tick_params(labelsize=10)
plt.show()

# %%
# Creating a scatterplot comparing IMR and per capita GDP
fig, axs = plt.subplots(figsize=(7,6))
axs.scatter(df['State_Per_Capita_GDP'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs per capita GDP", fontsize=16, fontweight="bold")
axs.set_xlabel("State per capita GDP (USD)", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
plt.show()

# %%
# Calculating correlation coefficient for state per capita GDP and IMR
corr = stats.pearsonr(df['State_Per_Capita_GDP'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: -0.3989468519717382
# p-value: 0.004106895577827369

# %%
# Getting statistics for per capita GDP and IMR
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

x_vals = df['State_Per_Capita_GDP'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.159
# Model:                               OLS   Adj. R-squared:                  0.142
# Method:                    Least Squares   F-statistic:                     9.086
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):            0.00411
# Time:                           14:46:47   Log-Likelihood:                -78.825
# No. Observations:                     50   AIC:                             161.6
# Df Residuals:                         48   BIC:                             165.5
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Creating a scatterplot comparing IMR and median earnings
fig, axs = plt.subplots(figsize=(7,6))
axs.scatter(df['MedianEarnings'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs Median Earnings", fontsize=16, fontweight="bold")
axs.set_xlabel("Median Earnings (USD)", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
plt.show()

# %%
# Calculating correlation coefficient for median earnings and IMR
corr = stats.pearsonr(df['MedianEarnings'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: -0.37842275792623437
# p-value: 0.006733292276394135

# %%
# Getting statistics for median earnings and IMR
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

x_vals = df['MedianEarnings'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.143
# Model:                               OLS   Adj. R-squared:                  0.125
# Method:                    Least Squares   F-statistic:                     8.023
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):            0.00673
# Time:                           14:46:47   Log-Likelihood:                -79.294
# No. Observations:                     50   AIC:                             162.6
# Df Residuals:                         48   BIC:                             166.4
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Creating a scatterplot comparing IMR and poverty rate
fig, axs = plt.subplots(figsize=(7,6))
axs.scatter(df['Poverty_Rate'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs Poverty Rate", fontsize=16, fontweight="bold")
axs.set_xlabel("Poverty Rate", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
plt.show()

# %%
# Calculating correlation coefficient for poverty rate and IMR
corr = stats.pearsonr(df['Poverty_Rate'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: 0.5780080945937915
# p-value: 1.1044289211435866e-05

# %%
# Getting statistics for poverty rate and IMR
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

x_vals = df['Poverty_Rate'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.334
# Model:                               OLS   Adj. R-squared:                  0.320
# Method:                    Least Squares   F-statistic:                     24.08
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):           1.10e-05
# Time:                           14:46:47   Log-Likelihood:                -72.993
# No. Observations:                     50   AIC:                             150.0
# Df Residuals:                         48   BIC:                             153.8
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Creating a scatterplot comparing IMR and child poverty rate
fig, axs = plt.subplots(figsize=(7,6))
axs.scatter(df['Child_Poverty'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs Child Poverty Rate", fontsize=16, fontweight="bold")
axs.set_xlabel("Child Poverty Rate", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
plt.show()

# %%
# Calculating correlation coefficient for child poverty rate and IMR
corr = stats.pearsonr(df['Child_Poverty'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: 0.6152064910303772
# p-value: 1.993841701489514e-06

# %%
# Getting statistics for child poverty and IMR
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

x_vals = df['Child_Poverty'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.378
# Model:                               OLS   Adj. R-squared:                  0.366
# Method:                    Least Squares   F-statistic:                     29.23
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):           1.99e-06
# Time:                           14:46:48   Log-Likelihood:                -71.269
# No. Observations:                     50   AIC:                             146.5
# Df Residuals:                         48   BIC:                             150.4
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Categorizing states by whether their IMR is above or below the 50-state median
def categorize_by_IMR(row):
    '''(number) -> string
    Return whether a State's infant mortality rate is above or below the US mean.
    '''
    if row['Infant_Mortality_Rate'] > IMR_mean:
        return 'Above'
    elif row['Infant_Mortality_Rate'] < IMR_mean :
        return 'Below'

df['IMRComparata'] = df.apply(categorize_by_IMR, axis=1)

IMR_data = df[['State', 'Infant_Mortality_Rate', 'IMRComparata']]
IMR_data.head()
# Out:
#         State  Infant_Mortality_Rate IMRComparata
# 0     Alabama                   8.71        Above
# 1      Alaska                   3.75        Below
# 2     Arizona                   5.97        Below
# 3    Arkansas                   7.32        Above
# 4  California                   4.74        Below

# %%
# Calculating the 50-state mean and median child poverty rate
df_child_poverty = df['Child_Poverty']
child_pov_mean = np.mean(df_child_poverty)
child_pov_median = np.median(df_child_poverty)

print("The mean child poverty rate for all 50 states is:", child_pov_mean)
print("The median child poverty rate for all 50 states is:", child_pov_median)
# Out:
# The mean child poverty rate for all 50 states is: 20.299400000000002
# The median child poverty rate for all 50 states is: 19.255000000000003

# %%
# Categorizing states by whether their child poverty rate is above or below the 50-state mean
def categorize_by_childpov(row):
    '''(number) -> string
    Return whether a State's child poverty rate is above or below the US mean.
    '''
    if row['Child_Poverty'] > child_pov_mean:
        return 'Above'
    elif row['Child_Poverty'] < child_pov_mean:
        return 'Below'

df['ChildPov_Comparata'] = df.apply(categorize_by_childpov, axis=1)

IMR_data = df[['State', 'Child_Poverty', 'ChildPov_Comparata']]
IMR_data.head()
# Out:
#         State  Child_Poverty ChildPov_Comparata
# 0     Alabama          27.72              Above
# 1      Alaska          12.91              Below
# 2     Arizona          24.42              Above
# 3    Arkansas          27.61              Above
# 4  California          21.98              Above

# %%
# Creating a 2-way frequency table IMR Comparata and ChildPov Comparata
table = pd.crosstab(index=df["IMRComparata"], columns=df["ChildPov_Comparata"]) 
table
# Out:
# ChildPov_Comparata  Above  Below
# IMRComparata
# Above                  16     10
# Below                   7     17

# %%
# Creating a 2-way frequency table IMR Comparata and ChildPov Comparata
percentage_table = table / table.sum(axis=0)
percentage_table
# Out:
# ChildPov_Comparata     Above    Below
# IMRComparata
# Above               0.695652  0.37037
# Below               0.304348  0.62963

# %%
# Creating a bar chart for IMR and child poverty
x_values = ['w/ Above-Mean\nChild Poverty Rate', 'w/ Below-Mean\nChild Poverty Rate']
y_values = [16/23,10/27]

fig, axs = plt.subplots(figsize=(5,6))     
axs.bar(x_values, y_values, color=('teal')) 
axs.set_title("Infant Mortality Rates and\nChild Poverty Rates", fontsize=14, fontweight="bold")   
axs.set_xlabel("States", fontsize=12)
axs.set_ylabel("Proportion of States with Above-Mean IMR", fontsize=12)
axs.tick_params(labelsize=9)  
plt.show()

# %%
# Finding the CI for proportion for above-mean IMR and above-mean child poverty rate
def CI_prop(s, n):
    p = s / n
    se2 = p * (1-p) / n
    se = np.sqrt(se2)
    low = p - 1.96 * se
    up = p + 1.96 * se
    print('Sample proportion is:', p)
    print('95% CI is: ({}, {})'.format(low, up))
    
CI_prop(16,23)
# Out:
# Sample proportion is: 0.6956521739130435
# 95% CI is: (0.5076021778504267, 0.8837021699756602)

# %%
# Finding the CI for proportion for above-mean IMR and below-mean child poverty rate
def CI_prop(s, n):
    p = s / n
    se2 = p * (1-p) / n
    se = np.sqrt(se2)
    low = p - 1.96 * se
    up = p + 1.96 * se
    print('Sample proportion is:', p)
    print('95% CI is: ({}, {})'.format(low, up))
    
CI_prop(10,27)
# Out:
# Sample proportion is: 0.37037037037037035
# 95% CI is: (0.188217975393852, 0.5525227653468887)

# %%
# Performing chi-square test for IMR comparata and child poverty comparata
chi2, p, dof, expected = stats.chi2_contingency(table)
print("chi2:", chi2)
print("p:", p)
print("dof:", dof)
print("expected:", expected)
# Out:
# chi2: 4.042409884801187
# p: 0.044370418060408236
# dof: 1
# expected: [[11.96 14.04]
#  [11.04 12.96]]

# %%
# Calculating 95% CI for proportion difference for IMR and child poverty
def CI_prop_diff(s1, s2, n1, n2):
    p1 = s1 / n1
    p2 = s2 / n2
    se2p1 = p1 * (1 - p1) / n1
    se2p2 = p2 * (1 - p2) / n2
    se2 = se2p1 + se2p2
    se = np.sqrt(se2)
    low = (p1 - p2) - 1.96 * se
    up = (p1 - p2) + 1.96 * se
    print("Proportion difference is:", p1 - p2)
    print("95% CI is: ({}, {})".format(low, up))
    
CI_prop_diff(s1=10, s2=16, n1=27, n2=23)
# Out:
# Proportion difference is: -0.3252818035426731
# 95% CI is: (-0.5870876400223661, -0.06347596706298014)

# %%
# Categorizing states by 1860 status
def categorize_by_1860_status(row):
    '''(number) -> string
    Return whether a State should be counted as a slave state or a free state
    for the purposes of the chi-square test
    '''
    if row['1860_Status'] == "Free":
        return 'Free'
    if row['1860_Status'] == "NotApplicable":
        return 'Free'
    if row['1860_Status'] == "OpenSlave":
        return 'Slave'
    elif row['1860_Status'] == "Slave":
        return 'Slave'
    
df['1860_status_2_cat'] = df.apply(categorize_by_1860_status, axis=1)

IMR_data = df[['State', '1860_Status', '1860_status_2_cat']]
IMR_data.head()
# Out:
#         State    1860_Status 1860_status_2_cat
# 0     Alabama          Slave             Slave
# 1      Alaska  NotApplicable              Free
# 2     Arizona      OpenSlave             Slave
# 3    Arkansas          Slave             Slave
# 4  California           Free              Free

# %%
# Producing value counts for 1860 status
df['1860_status_2_cat'].value_counts()
# Out:
# Slave    26
# Free     24
# Name: 1860_status_2_cat, dtype: int64

# %%
# Creating boxplots for mean IMR for slave states and free states
IMR_data = df[['State', '1860_status_2_cat', 'Infant_Mortality_Rate']]

slave_states = df[(IMR_data['1860_status_2_cat'] == 'Slave')]
free_states = df[(IMR_data['1860_status_2_cat'] == 'Free')]

slave_states_IMR = slave_states['Infant_Mortality_Rate']
free_states_IMR = free_states['Infant_Mortality_Rate']

fig, axs = plt.subplots(figsize=(6,6))
axs.boxplot([slave_states_IMR, free_states_IMR])
plt.title('Infant Mortality Rates for\nSlave and Free States', fontsize=13,fontweight="bold")
axs.set_xticklabels(['Slave\nStates', 'Free\nStates'])
axs.set_ylabel('Infant Mortality Rate (per 1,000 live births)', fontsize=11)
axs.tick_params(labelsize=11)
plt.show()

# %%
# Performing means test for slave states
def CI_mean(data):
    se = np.std(data)/np.sqrt(len(data))
    low = np.mean(data)-1.96*se
    up = np.mean(data)+1.96*se
    print("Average is:", np.mean(data))
    print("95% CI of mean is: ({}, {})".format(low,up))

CI_mean(slave_states['Infant_Mortality_Rate'])
# Out:
# Average is: 6.7515384615384635
# 95% CI of mean is: (6.35565984154738, 7.147417081529547)

# %%
# Performing one sample t-test for slave states
t_val, p_val = stats.ttest_1samp(slave_states['Infant_Mortality_Rate'].dropna(), 6.14)
print("Test statistic:", t_val)
print("p-value:", p_val)
# Out:
# Test statistic: 2.968938013793617
# p-value: 0.006505227789919152

# %%
# Performing means test for free states
CI_mean(free_states['Infant_Mortality_Rate'])
# Out:
# Average is: 5.637499999999999
# 95% CI of mean is: (5.131275677057206, 6.143724322942792)

# %%
# Performing one sample t-test for free states
t_val, p_val = stats.ttest_1samp(free_states['Infant_Mortality_Rate'].dropna(), 6.14)
print("Test statistic:", t_val)
print("p-value:", p_val)
# Out:
# Test statistic: -1.904615991406825
# p-value: 0.06941121139590922

# %%
# Performing means difference test for slave and free states
def CI_mean_diff(list1, list2):
    s1 = np.var(list1)
    s2 = np.var(list2)
    n1 = len(list1)
    n2 = len(list2)
    se2 = s1/n1 + s2/n2
    se = np.sqrt(se2)

    diff = np.mean(list1) - np.mean(list2)
    low = diff - 1.96 * se
    up = diff + 1.96 * se
    print("The average difference is:", diff)
    print("The 95% CI is: ({}, {})".format(low, up))
    
CI_mean_diff(slave_states['Infant_Mortality_Rate'], free_states['Infant_Mortality_Rate'])
# Out:
# The average difference is: 1.1140384615384642
# The 95% CI is: (0.4714009689309029, 1.7566759541460255)

# %%
# Performing two sample t-test
t_val, p_val = stats.ttest_ind(slave_states['Infant_Mortality_Rate'], free_states['Infant_Mortality_Rate'], equal_var=False)

print("Test statistic:", t_val)
print("p-value:", p_val)
# Out:
# Test statistic: 3.328306755722259
# p-value: 0.0017631156171342372

# %%
# Categorizing states by 1860 plantation status
def categorize_by_1860_plantation_status(row):
    '''(number) -> string
    Return whether a State should be counted as a plantation slave state,
    a slave state or a free state
    '''
    if row['Plantation'] == "Free":
        return 'Free'
    if row['Plantation'] == "NotApplicable":
        return 'Free'
    if row['Plantation'] == "SlavePlantation":
        return 'SlavePlantation'
    elif row['Plantation'] == "Slave":
        return 'Slave'
    
df['1860_status_plantation_cat'] = df.apply(categorize_by_1860_plantation_status, axis=1)

IMR_data = df[['State', 'Plantation', '1860_status_plantation_cat']]
IMR_data.head()
# Out:
#         State       Plantation 1860_status_plantation_cat
# 0     Alabama  SlavePlantation            SlavePlantation
# 1      Alaska    NotApplicable                       Free
# 2     Arizona            Slave                      Slave
# 3    Arkansas  SlavePlantation            SlavePlantation
# 4  California             Free                       Free

# %%
# Producing value counts for plantation status
df['1860_status_plantation_cat'].value_counts()
# Out:
# Free               24
# Slave              14
# SlavePlantation    12
# Name: 1860_status_plantation_cat, dtype: int64

# %%
# Creating a 2-way frequency table
table = pd.crosstab(index=df["IMRComparata"], columns=df["1860_status_plantation_cat"])
table
# Out:
# 1860_status_plantation_cat  Free  Slave  SlavePlantation
# IMRComparata
# Above                          8      7               11
# Below                         16      7                1

# %%
IMR_data_bis = df[['State', '1860_status_plantation_cat', 'Infant_Mortality_Rate']]

plantation_states = df[(IMR_data_bis['1860_status_plantation_cat'] == 'SlavePlantation')]
slave_states = df[(IMR_data_bis['1860_status_plantation_cat'] == 'Slave')]
free_states = df[(IMR_data_bis['1860_status_plantation_cat'] == 'Free')]

plantation_states_IMR = plantation_states['Infant_Mortality_Rate']
slave_states_IMR = slave_states['Infant_Mortality_Rate']
free_states_IMR = free_states['Infant_Mortality_Rate']

fig, axs = plt.subplots(figsize=(6,6))
axs.boxplot([plantation_states_IMR, slave_states_IMR, free_states_IMR])
plt.title('Infant Mortality Rates for\nPlantation Slave, Slave and Free States', fontsize=13,fontweight="bold")
axs.set_xticklabels(['Plantation\nSlave\nStates','Slave\nStates', 'Free\nStates'])
axs.set_ylabel('Infant Mortality Rate (per 1,000 live births)', fontsize=11)
axs.tick_params(labelsize=11)
plt.show()

# %%
# Performing means test for plantation slave states
def CI_mean(data):
    se = np.std(data)/np.sqrt(len(data))
    low = np.mean(data)-1.96*se
    up = np.mean(data)+1.96*se
    print("Average is:", np.mean(data))
    print("95% CI of mean is: ({}, {})".format(low,up))

CI_mean(plantation_states['Infant_Mortality_Rate'])
# Out:
# Average is: 7.363333333333333
# 95% CI of mean is: (6.815188353863013, 7.911478312803654)

# %%
# Performing means test for non-plantation slave states
def CI_mean(data):
    se = np.std(data)/np.sqrt(len(data))
    low = np.mean(data)-1.96*se
    up = np.mean(data)+1.96*se
    print("Average is:", np.mean(data))
    print("95% CI of mean is: ({}, {})".format(low,up))

CI_mean(slave_states['Infant_Mortality_Rate'])
# Out:
# Average is: 6.227142857142857
# 95% CI of mean is: (5.831814841439441, 6.6224708728462724)

# %%
# Performing means test for free states
def CI_mean(data):
    se = np.std(data)/np.sqrt(len(data))
    low = np.mean(data)-1.96*se
    up = np.mean(data)+1.96*se
    print("Average is:", np.mean(data))
    print("95% CI of mean is: ({}, {})".format(low,up))

CI_mean(free_states['Infant_Mortality_Rate'])
# Out:
# Average is: 5.637499999999999
# 95% CI of mean is: (5.131275677057206, 6.143724322942792)

# %%
# Performing means difference test for plantation slave states and free states
def CI_mean_diff(list1, list2):
    s1 = np.var(list1)
    s2 = np.var(list2)
    n1 = len(list1)
    n2 = len(list2)
    se2 = s1/n1 + s2/n2
    se = np.sqrt(se2)

    diff = np.mean(list1) - np.mean(list2)
    low = diff - 1.96 * se
    up = diff + 1.96 * se
    print("The average difference is:", diff)
    print("The 95% CI is: ({}, {})".format(low, up))
    
CI_mean_diff(plantation_states['Infant_Mortality_Rate'], free_states['Infant_Mortality_Rate'])
# Out:
# The average difference is: 1.725833333333334
# The 95% CI is: (0.9796926068899856, 2.4719740597766826)

# %%
# Performing two sample t-test
t_val, p_val = stats.ttest_ind(plantation_states['Infant_Mortality_Rate'], free_states['Infant_Mortality_Rate'], equal_var=False)

print("Test statistic:", t_val)
print("p-value:", p_val)
# Out:
# Test statistic: 4.384598053264492
# p-value: 0.00015356934801013066

# %%
# Creating bar chart for OECD countries' IMR
label = ['Iceland','Japan','Finland','Slovenia','Sweden','Norway','Denmark','Germany','Netherlands','Switzerland','Ireland','France','Austria','South Korea','Italy','Belgium','Greece','Canada','Luxembourg','Australia','Portugal','Spain','UK','Czechia','Turkey','Hungary','Slovakia','New Zealand','Mexico','Poland','Israel','Estonia','Chile','USA']
data = [47,51,58,66,67,72,73,79,82,82,88,98,98,99,106,108,111,118,122,130,136,147,147,154,179,186,187,192,210,217,223,238,266,710]
colors = ['teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','teal','orangered']

fig, axs = plt.subplots(figsize=(22,10))
axs.bar(label, data, color=colors)
axs.set_title("Incarceration Rate in OECD Countries (2012)", fontsize=20, fontweight="bold")   
axs.set_xlabel("Country", fontsize=25)
axs.set_ylabel("Incarceration Rate (per 100,000 residents)", fontsize=20)
axs.tick_params(labelsize=15, labelrotation=90)  
plt.grid(axis='y')
plt.show()

# %%
# Calculating correlation coefficient for incarceration rate and IMR
corr = stats.pearsonr(df['Incarceration_Rate'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: 0.6015027470912939
# p-value: 3.841409270129415e-06

# %%
# Getting statistics for incarceration rate and IMR
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

x_vals = df['Incarceration_Rate'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.362
# Model:                               OLS   Adj. R-squared:                  0.349
# Method:                    Least Squares   F-statistic:                     27.21
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):           3.84e-06
# Time:                           14:46:49   Log-Likelihood:                -71.931
# No. Observations:                     50   AIC:                             147.9
# Df Residuals:                         48   BIC:                             151.7
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Obtaining regression coefficients
b0 = reg_model.params[0]
b1 = reg_model.params[1]
x_plot = np.linspace(np.min(df['Incarceration_Rate']), np.max(df['Incarceration_Rate']), 100)

# %%
# Creating a scatterplot comparing IMR and incarceration rate for all states
fig, axs = plt.subplots(figsize=(9,6))
axs.scatter(df['Incarceration_Rate'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs Incarceration_Rate", fontsize=16, fontweight="bold")
plt.text(569,6.5, "IMR = Incarceration Rate * 0.0052 + 4.0643\nR-squared = 0.362",
        fontsize=9, color='orangered')
axs.set_xlabel("Incarceration Rate (per 100,000 inhabitants)", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
axs.plot(x_plot, x_plot*b1 + b0, color='orangered')
plt.show()

# %%
# Calculating correlation coefficient for teen pregnancies and IMR
corr = stats.pearsonr(df['Births_Teen_Girls'], df['Infant_Mortality_Rate'])
print('Correlation coefficient:', corr[0])
print('p-value:', corr[1])
# Out:
# Correlation coefficient: 0.593379904590539
# p-value: 5.586624527915107e-06

# %%
# Getting statistics for teen pregnancies and IMR
x_vals = df['Births_Teen_Girls'].values
y_vals = df['Infant_Mortality_Rate']

reg_model = OLS(y_vals, sm.add_constant(x_vals)).fit()
display(reg_model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant_Mortality_Rate   R-squared:                       0.352
# Model:                               OLS   Adj. R-squared:                  0.339
# Method:                    Least Squares   F-statistic:                     26.09
# Date:                   Sat, 19 Nov 2022   Prob (F-statistic):           5.59e-06
# Time:                           14:46:49   Log-Likelihood:                -72.308
# No. Observations:                     50   AIC:                             148.6
# Df Residuals:                         48   BIC:                             152.4
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Obtaining regression coefficients
b0 = reg_model.params[0]
b1 = reg_model.params[1]
x_plot = np.linspace(np.min(df['Births_Teen_Girls']), np.max(df['Births_Teen_Girls']), 100)

# %%
# Creating a scatterplot comparing IMR and births to teen girls for all states
fig, axs = plt.subplots(figsize=(9,6))
axs.scatter(df['Births_Teen_Girls'], df['Infant_Mortality_Rate'], c='teal', edgecolors='none', s=30)
plt.title("Infant Mortality Rate vs Births to Teen Girls", fontsize=16, fontweight="bold")
plt.text(38,4.8, "IMR = Birth to Teen Girls * 0.0758 + 3.6379\nR-squared = 0.352",
        fontsize=9, color='orangered')
axs.set_xlabel("Births to Teen Girls (per 1,000 age 15-19)", fontsize=14)
axs.set_ylabel("Infant Mortality Rate (per 1,000 live births)", fontsize=14)
axs.tick_params(labelsize=12)
axs.plot(x_plot, x_plot*b1 + b0, color='orangered')
plt.show()
